# %% [markdown]
# <a href="https://colab.research.google.com/github/luckfalcon520/colab-WebUI/blob/main/Colab-WebUI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GPT-SoVITS WebUI

# %% [markdown]
# ## Env Setup (Run Once Only)
# ## 环境配置, 只需运行一次

# %% [markdown]
# ### 1.

# %%
# %%writefile /content/setup.sh
# set -e
#
# cd /content
#
# git clone https://github.com/RVC-Boss/GPT-SoVITS.git
#
# cd GPT-SoVITS
#
# if conda env list | awk '{print $1}' | grep -Fxq "GPTSoVITS"; then
#     :
# else
#     conda create -n GPTSoVITS python=3.10 -y
# fi
#
# source activate GPTSoVITS
#
# pip install ipykernel
#
# bash install.sh --device CU126 --source HF --download-uvr5
# Out:
# Writing /content/setup.sh

# %% [markdown]
# ### 2.

# %%
# %pip install -q condacolab
import condacolab
condacolab.install_from_url("https://repo.anaconda.com/archive/Anaconda3-2024.10-1-Linux-x86_64.sh")
# !cd /content && bash setup.sh
# Out:
# ⏬ Downloading https://repo.anaconda.com/archive/Anaconda3-2024.10-1-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:01:53
# 🔁 Restarting kernel...
# Cloning into 'GPT-SoVITS'...
# remote: Enumerating objects: 5832, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 5832 (delta 16), reused 5 (delta 5), pack-reused 5799 (from 2)
# Receiving objects: 100% (5832/5832), 14.07 MiB | 14.31 MiB/s, done.
# Resolving deltas: 100% (3340/3340), done.
# Channels:
#  - defaults
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/GPTSoVITS
#
#   added / updated specs:
#     - python=3.10
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2026.3.19  |       h06a4308_0         126 KB
#     ld_impl_linux-64-2.44      |       h9e0c5a2_3         725 KB
#     libexpat-2.7.5             |       h7354ed3_0         122 KB
#     libgcc-15.2.0              |       h69a1729_7         806 KB
#     libgcc-ng-15.2.0           |       h166f726_7          28 KB
#     libgomp-15.2.0             |       h4751f2c_7         436 KB
#     libnsl-2.0.0               |       h5eee18b_0          31 KB
#     libstdcxx-15.2.0           |       h39759b7_7         3.7 MB
#     libstdcxx-ng-15.2.0        |       hc03a8fd_7          28 KB
#     libxcb-1.17.0              |       h9b100fa_0         430 KB
#     libzlib-1.3.1              |       hb25bd0a_0          59 KB
#     ncurses-6.5                |       h7934f7d_0         1.1 MB
#     openssl-3.5.5              |       h1b28b03_0         5.5 MB
#     packaging-26.0             |  py310h06a4308_0         165 KB
#     pip-26.0.1                 |     pyhc872135_1         1.1 MB
#     pthread-stubs-0.3          |       h0ce48e5_1           5 KB
#     python-3.10.20             |       h741d88c_0        24.1 MB
#     readline-8.3               |       hc2a1206_0         471 KB
#     setuptools-82.0.1          |  py310h06a4308_0         1.2 MB
#     sqlite-3.51.2              |       h3e8d24a_0         1.2 MB
#     tk-8.6.15                  |       h54e0aa7_0         3.4 MB
#     tzdata-2026a               |       he532380_0         117 KB
#     wheel-0.46.3               |  py310h06a4308_0          54 KB
#     xorg-libx11-1.8.12         |       h9b100fa_1         895 KB
#     xorg-libxau-1.0.12         |       h9b100fa_0          13 KB
#     xorg-libxdmcp-1.1.5        |       h9b100fa_0          19 KB
#     xorg-xorgproto-2024.1      |       h5eee18b_1         580 KB
#     xz-5.8.2                   |       h448239c_0         621 KB
#     zlib-1.3.1                 |       hb25bd0a_0          96 KB
#     ------------------------------------------------------------
#                                            Total:        47.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      pkgs/main/linux-64::_libgcc_mutex-0.1-main
#   _openmp_mutex      pkgs/main/linux-64::_openmp_mutex-5.1-1_gnu
#   bzip2              pkgs/main/linux-64::bzip2-1.0.8-h5eee18b_6
#   ca-certificates    pkgs/main/linux-64::ca-certificates-2026.3.19-h06a4308_0
#   ld_impl_linux-64   pkgs/main/linux-64::ld_impl_linux-64-2.44-h9e0c5a2_3
#   libexpat           pkgs/main/linux-64::libexpat-2.7.5-h7354ed3_0
#   libffi             pkgs/main/linux-64::libffi-3.4.4-h6a678d5_1
#   libgcc             pkgs/main/linux-64::libgcc-15.2.0-h69a1729_7
#   libgcc-ng          pkgs/main/linux-64::libgcc-ng-15.2.0-h166f726_7
#   libgomp            pkgs/main/linux-64::libgomp-15.2.0-h4751f2c_7
#   libnsl             pkgs/main/linux-64::libnsl-2.0.0-h5eee18b_0
#   libstdcxx          pkgs/main/linux-64::libstdcxx-15.2.0-h39759b7_7
#   libstdcxx-ng       pkgs/main/linux-64::libstdcxx-ng-15.2.0-hc03a8fd_7
#   libuuid            pkgs/main/linux-64::libuuid-1.41.5-h5eee18b_0
#   libxcb             pkgs/main/linux-64::libxcb-1.17.0-h9b100fa_0
#   libzlib            pkgs/main/linux-64::libzlib-1.3.1-hb25bd0a_0
#   ncurses            pkgs/main/linux-64::ncurses-6.5-h7934f7d_0
#   openssl            pkgs/main/linux-64::openssl-3.5.5-h1b28b03_0
#   packaging          pkgs/main/linux-64::packaging-26.0-py310h06a4308_0
#   pip                pkgs/main/noarch::pip-26.0.1-pyhc872135_1
#   pthread-stubs      pkgs/main/linux-64::pthread-stubs-0.3-h0ce48e5_1
#   python             pkgs/main/linux-64::python-3.10.20-h741d88c_0
#   readline           pkgs/main/linux-64::readline-8.3-hc2a1206_0
#   setuptools         pkgs/main/linux-64::setuptools-82.0.1-py310h06a4308_0
#   sqlite             pkgs/main/linux-64::sqlite-3.51.2-h3e8d24a_0
#   tk                 pkgs/main/linux-64::tk-8.6.15-h54e0aa7_0
#   tzdata             pkgs/main/noarch::tzdata-2026a-he532380_0
#   wheel              pkgs/main/linux-64::wheel-0.46.3-py310h06a4308_0
#   xorg-libx11        pkgs/main/linux-64::xorg-libx11-1.8.12-h9b100fa_1
#   xorg-libxau        pkgs/main/linux-64::xorg-libxau-1.0.12-h9b100fa_0
#   xorg-libxdmcp      pkgs/main/linux-64::xorg-libxdmcp-1.1.5-h9b100fa_0
#   xorg-xorgproto     pkgs/main/linux-64::xorg-xorgproto-2024.1-h5eee18b_1
#   xz                 pkgs/main/linux-64::xz-5.8.2-h448239c_0
#   zlib               pkgs/main/linux-64::zlib-1.3.1-hb25bd0a_0
#
#
#
# Downloading and Extracting Packages:
# python-3.10.20       | 24.1 MB   | :   0% 0/1 [00:00<?, ?it/s]
# openssl-3.5.5        | 5.5 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
# libstdcxx-15.2.0     | 3.7 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
# tk-8.6.15            | 3.4 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# setuptools-82.0.1    | 1.2 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# sqlite-3.51.2        | 1.2 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# pip-26.0.1           | 1.1 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# ncurses-6.5          | 1.1 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# xorg-libx11-1.8.12   | 895 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# libgcc-15.2.0        | 806 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# ld_impl_linux-64-2.4 | 725 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# xz-5.8.2             | 621 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# xorg-xorgproto-2024. | 580 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# readline-8.3         | 471 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgomp-15.2.0       | 436 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libxcb-1.17.0        | 430 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# packaging-26.0       | 165 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2026 | 126 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libexpat-2.7.5       | 122 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.10.20       | 24.1 MB   | :   1% 0.010371914546920347/1 [00:00<00:09,  9.64s/it]
# openssl-3.5.5        | 5.5 MB    | :   3% 0.028160197561386015/1 [00:00<00:03,  3.56s/it]
#
# libstdcxx-15.2.0     | 3.7 MB    | :   4% 0.03777375249861476/1 [00:00<00:02,  2.65s/it]
#
#
# tk-8.6.15            | 3.4 MB    | :  20% 0.1996841709598494/1 [00:00<00:00,  1.98it/s]
#
#
#
# setuptools-82.0.1    | 1.2 MB    | :  44% 0.4373666734973804/1 [00:00<00:00,  4.36it/s]
#
#
#
#
# python-3.10.20       | 24.1 MB   | :  15% 0.14650329297524992/1 [00:00<00:01,  1.19s/it]
# openssl-3.5.5        | 5.5 MB    | :  71% 0.7096369785469276/1 [00:00<00:00,  4.12it/s]
#
#
#
#
#
# python-3.10.20       | 24.1 MB   | :  31% 0.3111574364076104/1 [00:00<00:00,  1.21it/s]
#
#
#
#
#
#
# ncurses-6.5          | 1.1 MB    | :   1% 0.014401655346517857/1 [00:00<00:20, 20.45s/it]
#
#
#
#
#
#
#
# xorg-libx11-1.8.12   | 895 KB    | :   2% 0.017882324178246957/1 [00:00<00:16, 17.19s/it]
#
#
#
#
#
#
#
#
# python-3.10.20       | 24.1 MB   | :  46% 0.4628466866563205/1 [00:00<00:00,  1.33it/s]
#
#
#
#
#
#
#
#
#
#
# xz-5.8.2             | 621 KB    | :   3% 0.02577535294802453/1 [00:00<00:15, 15.66s/it]
#
#
#
#
#
#
#
#
#
# ld_impl_linux-64-2.4 | 725 KB    | :   2% 0.0220760426968775/1 [00:00<00:17, 18.37s/it]
#
#
#
#
#
#
#
#
#
#
#
# xorg-xorgproto-2024. | 580 KB    | :   3% 0.02757436782092818/1 [00:00<00:15, 15.66s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# readline-8.3         | 471 KB    | :   3% 0.03400397653924861/1 [00:00<00:13, 13.62s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libxcb-1.17.0        | 430 KB    | :   4% 0.03717806167600808/1 [00:00<00:12, 12.96s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.10.20       | 24.1 MB   | :  68% 0.6780639135049177/1 [00:00<00:00,  1.62it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# packaging-26.0       | 165 KB    | :  10% 0.0968401640797702/1 [00:00<00:04,  5.41s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2026 | 126 KB    | :  13% 0.12703828051702348/1 [00:00<00:03,  4.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libexpat-2.7.5       | 122 KB    | :  13% 0.13097664899952835/1 [00:00<00:03,  4.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.10.20       | 24.1 MB   | :  92% 0.9172661927432683/1 [00:00<00:00,  1.88it/s]
#
#
# tk-8.6.15            | 3.4 MB    | : 100% 1.0/1 [00:00<00:00,  1.01s/it]
#
#
# tk-8.6.15            | 3.4 MB    | : 100% 1.0/1 [00:00<00:00,  1.01s/it]
#
#
#
#
# sqlite-3.51.2        | 1.2 MB    | : 100% 1.0/1 [00:01<00:00,  1.03it/s]
#
#
#
#
# sqlite-3.51.2        | 1.2 MB    | : 100% 1.0/1 [00:01<00:00,  1.03it/s]
#
#
#
# setuptools-82.0.1    | 1.2 MB    | : 100% 1.0/1 [00:01<00:00,  1.25s/it]
#
#
#
# setuptools-82.0.1    | 1.2 MB    | : 100% 1.0/1 [00:01<00:00,  1.25s/it]
#
# libstdcxx-15.2.0     | 3.7 MB    | : 100% 1.0/1 [00:01<00:00,  1.19s/it]
#
# libstdcxx-15.2.0     | 3.7 MB    | : 100% 1.0/1 [00:01<00:00,  1.19s/it]
#
#
#
#
#
#
#
# xorg-libx11-1.8.12   | 895 KB    | : 100% 1.0/1 [00:01<00:00,  1.32s/it]
#
#
#
#
#
#
#
# xorg-libx11-1.8.12   | 895 KB    | : 100% 1.0/1 [00:01<00:00,  1.32s/it]
#
#
#
#
#
# pip-26.0.1           | 1.1 MB    | : 100% 1.0/1 [00:01<00:00,  1.44s/it]
#
#
#
#
#
# pip-26.0.1           | 1.1 MB    | : 100% 1.0/1 [00:01<00:00,  1.44s/it]
# openssl-3.5.5        | 5.5 MB    | : 100% 1.0/1 [00:01<00:00,  4.12it/s]
#
#
#
#
#
#
#
#
# libgcc-15.2.0        | 806 KB    | : 100% 1.0/1 [00:01<00:00,  1.87s/it]
#
#
#
#
#
#
#
#
# libgcc-15.2.0        | 806 KB    | : 100% 1.0/1 [00:01<00:00,  1.87s/it]
#
#
#
#
#
#
#
#
#
# ld_impl_linux-64-2.4 | 725 KB    | : 100% 1.0/1 [00:02<00:00,  1.91s/it]
#
#
#
#
#
#
#
#
#
# ld_impl_linux-64-2.4 | 725 KB    | : 100% 1.0/1 [00:02<00:00,  1.91s/it]
#
#
#
#
#
#
#
#
#
#
# xz-5.8.2             | 621 KB    | : 100% 1.0/1 [00:02<00:00,  2.13s/it]
#
#
#
#
#
#
#
#
#
#
# xz-5.8.2             | 621 KB    | : 100% 1.0/1 [00:02<00:00,  2.13s/it]
#
#
#
#
#
#
#
#
#
#
#
# xorg-xorgproto-2024. | 580 KB    | : 100% 1.0/1 [00:02<00:00,  2.35s/it]
#
#
#
#
#
#
#
#
#
#
#
# xorg-xorgproto-2024. | 580 KB    | : 100% 1.0/1 [00:02<00:00,  2.35s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# readline-8.3         | 471 KB    | : 100% 1.0/1 [00:02<00:00,  2.40s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# readline-8.3         | 471 KB    | : 100% 1.0/1 [00:02<00:00,  2.40s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libxcb-1.17.0        | 430 KB    | : 100% 1.0/1 [00:02<00:00,  2.50s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libxcb-1.17.0        | 430 KB    | : 100% 1.0/1 [00:02<00:00,  2.50s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgomp-15.2.0       | 436 KB    | : 100% 1.0/1 [00:02<00:00,  2.56s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgomp-15.2.0       | 436 KB    | : 100% 1.0/1 [00:02<00:00,  2.56s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# packaging-26.0       | 165 KB    | : 100% 1.0/1 [00:02<00:00,  2.66s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# packaging-26.0       | 165 KB    | : 100% 1.0/1 [00:02<00:00,  2.66s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2026 | 126 KB    | : 100% 1.0/1 [00:02<00:00,  2.70s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2026 | 126 KB    | : 100% 1.0/1 [00:02<00:00,  2.70s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libexpat-2.7.5       | 122 KB    | : 100% 1.0/1 [00:02<00:00,  2.73s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libexpat-2.7.5       | 122 KB    | : 100% 1.0/1 [00:02<00:00,  2.73s/it]
#
#
#
#
#
#
# ncurses-6.5          | 1.1 MB    | : 100% 1.0/1 [00:03<00:00,  3.11s/it]
#
#
#
#
#
#
# ncurses-6.5          | 1.1 MB    | : 100% 1.0/1 [00:03<00:00,  3.11s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.10.20       | 24.1 MB   | : 100% 1.0/1 [00:04<00:00,  1.88it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate GPTSoVITS
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# Collecting ipykernel
#   Downloading ipykernel-7.2.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting comm>=0.1.1 (from ipykernel)
#   Downloading comm-0.2.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting debugpy>=1.6.5 (from ipykernel)
#   Downloading debugpy-1.8.20-cp310-cp310-manylinux_2_34_x86_64.whl.metadata (1.4 kB)
# Collecting ipython>=7.23.1 (from ipykernel)
#   Downloading ipython-8.39.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting jupyter-client>=8.8.0 (from ipykernel)
#   Downloading jupyter_client-8.8.0-py3-none-any.whl.metadata (8.4 kB)
# Collecting jupyter-core!=6.0.*,>=5.1 (from ipykernel)
#   Downloading jupyter_core-5.9.1-py3-none-any.whl.metadata (1.5 kB)
# Collecting matplotlib-inline>=0.1 (from ipykernel)
#   Downloading matplotlib_inline-0.2.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting nest-asyncio>=1.4 (from ipykernel)
#   Downloading nest_asyncio-1.6.0-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: packaging>=22 in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from ipykernel) (26.0)
# Collecting psutil>=5.7 (from ipykernel)
#   Downloading psutil-7.2.2-cp36-abi3-manylinux2010_x86_64.manylinux_2_12_x86_64.manylinux_2_28_x86_64.whl.metadata (22 kB)
# Collecting pyzmq>=25 (from ipykernel)
#   Downloading pyzmq-27.1.0-cp310-cp310-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl.metadata (6.0 kB)
# Collecting tornado>=6.4.1 (from ipykernel)
#   Downloading tornado-6.5.5-cp39-abi3-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (2.8 kB)
# Collecting traitlets>=5.4.0 (from ipykernel)
#   Downloading traitlets-5.14.3-py3-none-any.whl.metadata (10 kB)
# Collecting decorator (from ipython>=7.23.1->ipykernel)
#   Downloading decorator-5.2.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting exceptiongroup (from ipython>=7.23.1->ipykernel)
#   Downloading exceptiongroup-1.3.1-py3-none-any.whl.metadata (6.7 kB)
# Collecting jedi>=0.16 (from ipython>=7.23.1->ipykernel)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting pexpect>4.3 (from ipython>=7.23.1->ipykernel)
#   Downloading pexpect-4.9.0-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting prompt_toolkit<3.1.0,>=3.0.41 (from ipython>=7.23.1->ipykernel)
#   Downloading prompt_toolkit-3.0.52-py3-none-any.whl.metadata (6.4 kB)
# Collecting pygments>=2.4.0 (from ipython>=7.23.1->ipykernel)
#   Downloading pygments-2.20.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting stack_data (from ipython>=7.23.1->ipykernel)
#   Downloading stack_data-0.6.3-py3-none-any.whl.metadata (18 kB)
# Collecting typing_extensions>=4.6 (from ipython>=7.23.1->ipykernel)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting wcwidth (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel)
#   Downloading wcwidth-0.6.0-py3-none-any.whl.metadata (30 kB)
# Collecting parso<0.9.0,>=0.8.4 (from jedi>=0.16->ipython>=7.23.1->ipykernel)
#   Downloading parso-0.8.6-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting python-dateutil>=2.8.2 (from jupyter-client>=8.8.0->ipykernel)
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting platformdirs>=2.5 (from jupyter-core!=6.0.*,>=5.1->ipykernel)
#   Downloading platformdirs-4.9.4-py3-none-any.whl.metadata (4.7 kB)
# Collecting ptyprocess>=0.5 (from pexpect>4.3->ipython>=7.23.1->ipykernel)
#   Downloading ptyprocess-0.7.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting six>=1.5 (from python-dateutil>=2.8.2->jupyter-client>=8.8.0->ipykernel)
#   Downloading six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting executing>=1.2.0 (from stack_data->ipython>=7.23.1->ipykernel)
#   Downloading executing-2.2.1-py2.py3-none-any.whl.metadata (8.9 kB)
# Collecting asttokens>=2.1.0 (from stack_data->ipython>=7.23.1->ipykernel)
#   Downloading asttokens-3.0.1-py3-none-any.whl.metadata (4.9 kB)
# Collecting pure-eval (from stack_data->ipython>=7.23.1->ipykernel)
#   Downloading pure_eval-0.2.3-py3-none-any.whl.metadata (6.3 kB)
# Downloading ipykernel-7.2.0-py3-none-any.whl (118 kB)
# Downloading comm-0.2.3-py3-none-any.whl (7.3 kB)
# Downloading debugpy-1.8.20-cp310-cp310-manylinux_2_34_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 78.2 MB/s  0:00:00
# Downloading ipython-8.39.0-py3-none-any.whl (831 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 831.8/831.8 kB 54.2 MB/s  0:00:00
# Downloading prompt_toolkit-3.0.52-py3-none-any.whl (391 kB)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 68.9 MB/s  0:00:00
# Downloading parso-0.8.6-py2.py3-none-any.whl (106 kB)
# Downloading jupyter_client-8.8.0-py3-none-any.whl (107 kB)
# Downloading jupyter_core-5.9.1-py3-none-any.whl (29 kB)
# Downloading matplotlib_inline-0.2.1-py3-none-any.whl (9.5 kB)
# Downloading nest_asyncio-1.6.0-py3-none-any.whl (5.2 kB)
# Downloading pexpect-4.9.0-py2.py3-none-any.whl (63 kB)
# Downloading platformdirs-4.9.4-py3-none-any.whl (21 kB)
# Downloading psutil-7.2.2-cp36-abi3-manylinux2010_x86_64.manylinux_2_12_x86_64.manylinux_2_28_x86_64.whl (155 kB)
# Downloading ptyprocess-0.7.0-py2.py3-none-any.whl (13 kB)
# Downloading pygments-2.20.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 77.2 MB/s  0:00:00
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Downloading pyzmq-27.1.0-cp310-cp310-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl (854 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 854.1/854.1 kB 50.6 MB/s  0:00:00
# Downloading six-1.17.0-py2.py3-none-any.whl (11 kB)
# Downloading tornado-6.5.5-cp39-abi3-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (447 kB)
# Downloading traitlets-5.14.3-py3-none-any.whl (85 kB)
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading decorator-5.2.1-py3-none-any.whl (9.2 kB)
# Downloading exceptiongroup-1.3.1-py3-none-any.whl (16 kB)
# Downloading stack_data-0.6.3-py3-none-any.whl (24 kB)
# Downloading asttokens-3.0.1-py3-none-any.whl (27 kB)
# Downloading executing-2.2.1-py2.py3-none-any.whl (28 kB)
# Downloading pure_eval-0.2.3-py3-none-any.whl (11 kB)
# Downloading wcwidth-0.6.0-py3-none-any.whl (94 kB)
# Installing collected packages: pure-eval, ptyprocess, wcwidth, typing_extensions, traitlets, tornado, six, pyzmq, pygments, psutil, platformdirs, pexpect, parso, nest-asyncio, executing, decorator, debugpy, comm, asttokens, stack_data, python-dateutil, prompt_toolkit, matplotlib-inline, jupyter-core, jedi, exceptiongroup, jupyter-client, ipython, ipykernel
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29/29 [ipykernel]
# Successfully installed asttokens-3.0.1 comm-0.2.3 debugpy-1.8.20 decorator-5.2.1 exceptiongroup-1.3.1 executing-2.2.1 ipykernel-7.2.0 ipython-8.39.0 jedi-0.19.2 jupyter-client-8.8.0 jupyter-core-5.9.1 matplotlib-inline-0.2.1 nest-asyncio-1.6.0 parso-0.8.6 pexpect-4.9.0 platformdirs-4.9.4 prompt_toolkit-3.0.52 psutil-7.2.2 ptyprocess-0.7.0 pure-eval-0.2.3 pygments-2.20.0 python-dateutil-2.9.0.post0 pyzmq-27.1.0 six-1.17.0 stack_data-0.6.3 tornado-6.5.5 traitlets-5.14.3 typing_extensions-4.15.0 wcwidth-0.6.0
# [INFO]: Detected system: Linux 6.6.113+ x86_64
# [INFO]: Detected GCC Version: 11
# [INFO]: Skip Installing GCC & G++ From Conda-Forge
# [INFO]: Installing libstdcxx-ng From Conda-Forge
# [SUCCESS]: libstdcxx-ng=11 Installed...
# [INFO]: Installing FFmpeg & CMake...
# [SUCCESS]: FFmpeg & CMake Installed
# [INFO]: Installing unzip...
# [SUCCESS]: unzip Installed
# [INFO]: Download Model From HuggingFace
# [INFO]: Downloading Pretrained Models...
# pretrained_models.z 100%[===================>]   4.25G   258MB/s    in 23s
# [SUCCESS]: Pretrained Models Downloaded
# [INFO]: Downloading G2PWModel..
# G2PWModel.zip       100%[===================>] 561.58M   107MB/s    in 3.8s
# [SUCCESS]: G2PWModel Downloaded
# [INFO]: Downloading UVR5 Models...
# uvr5_weights.zip    100%[===================>] 498.70M   327MB/s    in 1.5s
# [SUCCESS]: UVR5 Models Downloaded
# [INFO]: Checking For Nvidia Driver Installation...
# \033[INFO]: \033Nvidia Driver Founded
# [INFO]: Installing PyTorch For CUDA 12.6...
# [SUCCESS]: PyTorch Installed
# [INFO]: Installing Python Dependencies From requirements.txt...
# [SUCCESS]: Python Dependencies Installed
# [INFO]: Downloading NLTK Data...
# nltk_data.zip       100%[===================>]   9.46M  --.-KB/s    in 0.07s
# [SUCCESS]: NLTK Data Downloaded
# [INFO]: Downloading Open JTalk Dict...
# open_jtalk_dic_utf_ 100%[===================>]  22.55M  --.-KB/s    in 0.09s
# [SUCCESS]: Open JTalk Dic Downloaded
# [SUCCESS]: Installation Completed

# %% [markdown]
# ## Launch WebUI
# ## 启动 WebUI

# %%
# !cd /content/GPT-SoVITS && source activate GPTSoVITS && export is_share=True && python webui.py
# Out:
# Running on local URL:  http://0.0.0.0:9874
# Running on public URL: https://1fca0d836750d006e2.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# "/usr/local/envs/GPTSoVITS/bin/python" -s tools/uvr5/webui.py "cuda:0" True 9873 True
# Running on local URL:  http://0.0.0.0:9873
# Running on public URL: https://3e4869652a7168104c.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !/usr/local/envs/GPTSoVITS/bin/pip uninstall -y gradio jinja2 markupsafe fastapi

# !/usr/local/envs/GPTSoVITS/bin/pip install \
gradio==4.24.0 \
jinja2==3.1.3 \
markupsafe==2.1.5 \
fastapi==0.110.0
# Out:
# Found existing installation: gradio 4.29.0
# Uninstalling gradio-4.29.0:
#   Successfully uninstalled gradio-4.29.0
# Found existing installation: Jinja2 3.1.3
# Uninstalling Jinja2-3.1.3:
#   Successfully uninstalled Jinja2-3.1.3
# Found existing installation: MarkupSafe 2.1.5
# Uninstalling MarkupSafe-2.1.5:
#   Successfully uninstalled MarkupSafe-2.1.5
# Found existing installation: fastapi 0.135.3
# Uninstalling fastapi-0.135.3:
#   Successfully uninstalled fastapi-0.135.3
# Collecting gradio==4.24.0
#   Downloading gradio-4.24.0-py3-none-any.whl.metadata (15 kB)
# Collecting jinja2==3.1.3
#   Using cached Jinja2-3.1.3-py3-none-any.whl.metadata (3.3 kB)
# Collecting markupsafe==2.1.5
#   Using cached MarkupSafe-2.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Collecting fastapi==0.110.0
#   Downloading fastapi-0.110.0-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from gradio==4.24.0) (23.2.1)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from gradio==4.24.0) (5.5.0)
# Requirement already satisfied: ffmpy in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from gradio==4.24.0) (1.0.0)
# Collecting gradio-client==0.14.0 (from gradio==4.24.0)
#   Downloading gradio_client-0.14.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: httpx>=0.24.1 in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from gradio==4.24.0) (0.28.1)
# Requirement already satisfied: huggingface-hub>=0.19.3 in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from gradio==4.24.0) (0.36.2)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from gradio==4.24.0) (6.5.2)
# Requirement already satisfied: matplotlib~=3.0 in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from gradio==4.24.0) (3.10.8)
# Requirement already satisfied: numpy~=1.0 in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from gradio==4.24.0) (1.26.4)
# Requirement already satisfied: orjson~=3.0 in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from gradio==4.24.0) (3.11.8)
# Requirement already satisfied: packaging in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from gradio==4.24.0) (26.0)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from gradio==4.24.0) (2.3.3)
# Requirement already satisfied: pillow<11.0,>=8.0 in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from gradio==4.24.0) (10.4.0)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from gradio==4.24.0) (2.10.6)
# Requirement already satisfied: pydub in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from gradio==4.24.0) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from gradio==4.24.0) (0.0.24)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from gradio==4.24.0) (6.0.3)
# Requirement already satisfied: ruff>=0.2.2 in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from gradio==4.24.0) (0.15.9)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from gradio==4.24.0) (2.10.0)
# Requirement already satisfied: tomlkit==0.12.0 in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from gradio==4.24.0) (0.12.0)
# Requirement already satisfied: typer<1.0,>=0.9 in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from typer[all]<1.0,>=0.9; sys_platform != "emscripten"->gradio==4.24.0) (0.24.1)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from gradio==4.24.0) (4.15.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from gradio==4.24.0) (0.44.0)
# Collecting starlette<0.37.0,>=0.36.3 (from fastapi==0.110.0)
#   Downloading starlette-0.36.3-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: fsspec in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from gradio-client==0.14.0->gradio==4.24.0) (2026.2.0)
# Requirement already satisfied: websockets<12.0,>=10.0 in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from gradio-client==0.14.0->gradio==4.24.0) (11.0.3)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from altair<6.0,>=4.2.0->gradio==4.24.0) (4.26.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from altair<6.0,>=4.2.0->gradio==4.24.0) (2.18.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from matplotlib~=3.0->gradio==4.24.0) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from matplotlib~=3.0->gradio==4.24.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from matplotlib~=3.0->gradio==4.24.0) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from matplotlib~=3.0->gradio==4.24.0) (1.5.0)
# Requirement already satisfied: pyparsing>=3 in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from matplotlib~=3.0->gradio==4.24.0) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from matplotlib~=3.0->gradio==4.24.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from pandas<3.0,>=1.0->gradio==4.24.0) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from pandas<3.0,>=1.0->gradio==4.24.0) (2026.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from pydantic>=2.0->gradio==4.24.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from pydantic>=2.0->gradio==4.24.0) (2.27.2)
# Requirement already satisfied: anyio<5,>=3.4.0 in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from starlette<0.37.0,>=0.36.3->fastapi==0.110.0) (4.13.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from anyio<5,>=3.4.0->starlette<0.37.0,>=0.36.3->fastapi==0.110.0) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from anyio<5,>=3.4.0->starlette<0.37.0,>=0.36.3->fastapi==0.110.0) (3.11)
# Requirement already satisfied: click>=8.2.1 in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from typer<1.0,>=0.9->typer[all]<1.0,>=0.9; sys_platform != "emscripten"->gradio==4.24.0) (8.3.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from typer<1.0,>=0.9->typer[all]<1.0,>=0.9; sys_platform != "emscripten"->gradio==4.24.0) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from typer<1.0,>=0.9->typer[all]<1.0,>=0.9; sys_platform != "emscripten"->gradio==4.24.0) (14.3.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from typer<1.0,>=0.9->typer[all]<1.0,>=0.9; sys_platform != "emscripten"->gradio==4.24.0) (0.0.4)
# WARNING: typer 0.24.1 does not provide the extra 'all'
# Requirement already satisfied: certifi in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from httpx>=0.24.1->gradio==4.24.0) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from httpx>=0.24.1->gradio==4.24.0) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.24.1->gradio==4.24.0) (0.16.0)
# Requirement already satisfied: filelock in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from huggingface-hub>=0.19.3->gradio==4.24.0) (3.25.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from huggingface-hub>=0.19.3->gradio==4.24.0) (1.4.3)
# Requirement already satisfied: requests in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from huggingface-hub>=0.19.3->gradio==4.24.0) (2.33.1)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from huggingface-hub>=0.19.3->gradio==4.24.0) (4.67.3)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==4.24.0) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==4.24.0) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==4.24.0) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==4.24.0) (0.30.0)
# Requirement already satisfied: six>=1.5 in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio==4.24.0) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from rich>=12.3.0->typer<1.0,>=0.9->typer[all]<1.0,>=0.9; sys_platform != "emscripten"->gradio==4.24.0) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from rich>=12.3.0->typer<1.0,>=0.9->typer[all]<1.0,>=0.9; sys_platform != "emscripten"->gradio==4.24.0) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer<1.0,>=0.9->typer[all]<1.0,>=0.9; sys_platform != "emscripten"->gradio==4.24.0) (0.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from requests->huggingface-hub>=0.19.3->gradio==4.24.0) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from requests->huggingface-hub>=0.19.3->gradio==4.24.0) (2.6.3)
# Downloading gradio-4.24.0-py3-none-any.whl (17.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 98.6 MB/s  0:00:00
# Using cached Jinja2-3.1.3-py3-none-any.whl (133 kB)
# Using cached MarkupSafe-2.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Downloading fastapi-0.110.0-py3-none-any.whl (92 kB)
# Downloading gradio_client-0.14.0-py3-none-any.whl (312 kB)
# Downloading starlette-0.36.3-py3-none-any.whl (71 kB)
# Installing collected packages: markupsafe, jinja2, starlette, gradio-client, fastapi, gradio
#   Attempting uninstall: starlette
#     Found existing installation: starlette 1.0.0
#     Uninstalling starlette-1.0.0:
#       Successfully uninstalled starlette-1.0.0
#   Attempting uninstall: gradio-client
#     Found existing installation: gradio_client 0.16.1
#     Uninstalling gradio_client-0.16.1:
#       Successfully uninstalled gradio_client-0.16.1
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [gradio]
# Successfully installed fastapi-0.110.0 gradio-4.24.0 gradio-client-0.14.0 jinja2-3.1.3 markupsafe-2.1.5 starlette-0.36.3
